# %% [markdown]
# # BANK CREDIT CARD:

# %%
import os 
os.chdir(r"C:\Users\venuk\OneDrive\Desktop\imarticus")
os.getcwd()
# Out:
# 'C:\\Users\\venuk\\OneDrive\\Desktop\\imarticus'

# %% [markdown]
# # EDA:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
my_data=pd.read_csv("BankCreditCard.csv")

# %%
my_data.head()
# Out:
#    Customer ID  Credit_Amount  Gender  Academic_Qualification  Marital  \
# 0            1        20000.0       2                       2        1
# 1            2       220000.0       2                       2        2
# 2            3        90000.0       2                       2        2
# 3            4        50000.0       2                       2        1
# 4            5        50000.0       1                       2        1
#
#    Age_Years  Repayment_Status_Jan  Repayment_Status_Feb  \
# 0         24                     2                     2
# 1         26                     0                     2
# 2         34                     0                     0
# 3         37                     0                     0
# 4         57                     0                     0
#
#    Repayment_Status_March  Repayment_Status_April  ...  April_Bill_Amount  \
# 0                       0                       0  ...                0.0
# 1                       0                       0  ...             3272.0
# 2                       0                       0  ...            24332.0
# 3                       0                       0  ...            29324.0
# 4                       0                       0  ...            20940.0
#
#    May_Bill_Amount  June_Bill_Amount  Previous_Payment_Jan  \
# 0              0.0               0.0                   0.0
# 1           3455.0            3261.0                   0.0
# 2          14848.0           15548.0                1619.0
# 3          28858.0           28547.0                3000.0
# 4          18146.0           18131.0                3000.0
#
#    Previous_Payment_Feb  Previous_Payment_March  Previous_Payment_April  \
# 0                 679.0                     0.0                     0.0
# 1                2000.0                  1000.0                  1000.0
# 2                2500.0                  1000.0                  1000.0
# 3                2029.0                  1200.0                  1100.0
# 4               36672.0                 10000.0                  9000.0
#
#    Previous_Payment_May  Previous_Payment_June  Default_Payment
# 0                   0.0                    0.0                1
# 1                   0.0                 2000.0                1
# 2                1000.0                 5000.0                0
# 3                1069.0                 1000.0                0
# 4                 689.0                  679.0                0
#
# [5 rows x 25 columns]

# %%
my_data.shape
# Out:
# (30000, 25)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             30000 non-null  int64
#  1   Credit_Amount           30000 non-null  float64
#  2   Gender                  30000 non-null  int64
#  3   Academic_Qualification  30000 non-null  int64
#  4   Marital                 30000 non-null  int64
#  5   Age_Years               30000 non-null  int64
#  6   Repayment_Status_Jan    30000 non-null  int64
#  7   Repayment_Status_Feb    30000 non-null  int64
#  8   Repayment_Status_March  30000 non-null  int64
#  9   Repayment_Status_April  30000 non-null  int64
#  10  Repayment_Status_May    30000 non-null  int64
#  11  Repayment_Status_June   30000 non-null  int64
#  12  Jan_Bill_Amount         30000 non-null  float64
#  13  Feb_Bill_Amount         30000 non-null  float64
#  14  March_Bill_Amount       30000 non-null  float64
#  15  April_Bill_Amount       30000 non-null  float64
#  16  May_Bill_Amount         30000 non-null  float64
#  17  June_Bill_Amount        30000 non-null  float64
#  18  Previous_Payment_Jan    30000 non-null  float64
#  19  Previous_Payment_Feb    30000 non-null  float64
#  20  Previous_Payment_March  30000 non-null  float64
#  21  Previous_Payment_April  30000 non-null  float64
#  22  Previous_Payment_May    30000 non-null  float64
#  23  Previous_Payment_June   30000 non-null  float64
#  24  Default_Payment         30000 non-null  int64
# dtypes: float64(13), int64(12)
# memory usage: 5.7 MB

# %%
my_data=my_data.drop("Customer ID",1)

# %%
my_data
# Out:
#        Credit_Amount  Gender  Academic_Qualification  Marital  Age_Years  \
# 0            20000.0       2                       2        1         24
# 1           220000.0       2                       2        2         26
# 2            90000.0       2                       2        2         34
# 3            50000.0       2                       2        1         37
# 4            50000.0       1                       2        1         57
# ...              ...     ...                     ...      ...        ...
# 29995       220000.0       1                       3        1         39
# 29996       250000.0       1                       3        2         43
# 29997        30000.0       1                       2        2         37
# 29998        80000.0       1                       3        1         41
# 29999        50000.0       1                       2        1         46
#
#        Repayment_Status_Jan  Repayment_Status_Feb  Repayment_Status_March  \
# 0                         2                     2                       0
# 1                         0                     2                       0
# 2                         0                     0                       0
# 3                         0                     0                       0
# 4                         0                     0                       0
# ...                     ...                   ...                     ...
# 29995                     0                     0                       0
# 29996                     0                     0                       0
# 29997                     4                     3                       2
# 29998                     1                     0                       0
# 29999                     0                     0                       0
#
#        Repayment_Status_April  Repayment_Status_May  ...  April_Bill_Amount  \
# 0                           0                     0  ...                0.0
# 1                           0                     0  ...             3272.0
# 2                           0                     0  ...            24332.0
# 3                           0                     0  ...            29324.0
# 4                           0                     0  ...            20940.0
# ...                       ...                   ...  ...                ...
# 29995                       0                     0  ...            99004.0
# 29996                       0                     0  ...             9979.0
# 29997                       0                     0  ...            20979.0
# 29998                       0                     0  ...            52774.0
# 29999                       0                     0  ...            36535.0
#
#        May_Bill_Amount  June_Bill_Amount  Previous_Payment_Jan  \
# 0                  0.0               0.0                   0.0
# 1               3455.0            3261.0                   0.0
# 2              14848.0           15548.0                1619.0
# 3              28858.0           28547.0                3000.0
# 4              18146.0           18131.0                3000.0
# ...                ...               ...                   ...
# 29995          31237.0           15880.0                9600.0
# 29996           5180.0               0.0                1937.0
# 29997          20582.0           18357.0                   0.0
# 29998          11855.0           48844.0               96900.0
# 29999          32428.0           15313.0                3079.0
#
#        Previous_Payment_Feb  Previous_Payment_March  Previous_Payment_April  \
# 0                     679.0                     0.0                     0.0
# 1                    2000.0                  1000.0                  1000.0
# 2                    2500.0                  1000.0                  1000.0
# 3                    2029.0                  1200.0                  1100.0
# 4                   36672.0                 10000.0                  9000.0
# ...                     ...                     ...                     ...
# 29995               20000.0                  5005.0                  3047.0
# 29996                3526.0                  9999.0                   139.0
# 29997                   0.0                 22000.0                  4300.0
# 29998                3409.0                  1179.0                  1935.0
# 29999                2700.0                  1550.0                  1000.0
#
#        Previous_Payment_May  Previous_Payment_June  Default_Payment
# 0                       0.0                    0.0                1
# 1                       0.0                 2000.0                1
# 2                    1000.0                 5000.0                0
# 3                    1069.0                 1000.0                0
# 4                     689.0                  679.0                0
# ...                     ...                    ...              ...
# 29995                5000.0                 1000.0                0
# 29996                   0.0                    0.0                0
# 29997                3000.0                 3100.0                1
# 29998               53965.0                 1804.0                1
# 29999                1000.0                 1000.0                1
#
# [30000 rows x 24 columns]

# %%
my_data.describe().T
# Out:
#                           count           mean            std       min  \
# Credit_Amount           30000.0  192917.322667  132288.752980   20000.0
# Gender                  30000.0       1.603733       0.489129       1.0
# Academic_Qualification  30000.0       1.855933       0.794397       1.0
# Marital                 30000.0       1.551867       0.521970       0.0
# Age_Years               30000.0      35.485500       9.217904      21.0
# Repayment_Status_Jan    30000.0       0.355200       0.746984       0.0
# Repayment_Status_Feb    30000.0       0.319300       0.796012       0.0
# Repayment_Status_March  30000.0       0.302967       0.781792       0.0
# Repayment_Status_April  30000.0       0.256700       0.743880       0.0
# Repayment_Status_May    30000.0       0.219500       0.699954       0.0
# Repayment_Status_June   30000.0       0.224900       0.700573       0.0
# Jan_Bill_Amount         30000.0   81581.060100  123026.372701 -365580.0
# Feb_Bill_Amount         30000.0   52517.103000   80401.365192  -58777.0
# March_Bill_Amount       30000.0   59003.885800   88417.468059 -257264.0
# April_Bill_Amount       30000.0   55122.263933   83577.329356 -270000.0
# May_Bill_Amount         30000.0   39939.618800   60373.934792  -81334.0
# June_Bill_Amount        30000.0   38506.051533   59104.280171 -338603.0
# Previous_Payment_Jan    30000.0    6285.653867   18944.920299       0.0
# Previous_Payment_Feb    30000.0    7466.543800   34679.497857       0.0
# Previous_Payment_March  30000.0    5836.140567   20696.306703       0.0
# Previous_Payment_April  30000.0    5127.687433   17103.762740       0.0
# Previous_Payment_May    30000.0    5261.191200   16989.506850       0.0
# Previous_Payment_June   30000.0    5215.502567   17777.465775       0.0
# Default_Payment         30000.0       0.221200       0.415062       0.0
#
#                              25%       50%        75%        max
# Credit_Amount           50000.00  220000.0  270000.00  2000000.0
# Gender                      1.00       2.0       2.00        2.0
# Academic_Qualification      1.00       2.0       2.00        6.0
# Marital                     1.00       2.0       2.00        3.0
# Age_Years                  28.00      34.0      41.00       79.0
# Repayment_Status_Jan        0.00       0.0       0.00        6.0
# Repayment_Status_Feb        0.00       0.0       0.00        6.0
# Repayment_Status_March      0.00       0.0       0.00        6.0
# Repayment_Status_April      0.00       0.0       0.00        6.0
# Repayment_Status_May        0.00       0.0       0.00        6.0
# Repayment_Status_June       0.00       0.0       0.00        6.0
# Jan_Bill_Amount          3890.00   35661.5   67091.00   964533.0
# Feb_Bill_Amount          3517.00   30538.0   57420.50   883831.0
# March_Bill_Amount        2876.00   26568.0   60252.50  2664089.0
# April_Bill_Amount        2671.50   25629.0   54508.50   992596.0
# May_Bill_Amount          1763.00   18043.0   50190.50   827171.0
# June_Bill_Amount         1256.00   17071.0   48655.25   861664.0
# Previous_Payment_Jan     1000.00    3000.0    6000.00   973663.0
# Previous_Payment_Feb      770.00    2542.0    5000.00  2674259.0
# Previous_Payment_March    550.00    1900.0    5500.00   999055.0
# Previous_Payment_April    333.00    1500.0    4013.25   538897.0
# Previous_Payment_May      310.00    1539.0    5000.00   536539.0
# Previous_Payment_June     117.75    1500.0    4000.00   528666.0
# Default_Payment             0.00       0.0       0.00        1.0

# %%
my_data.isna().sum()   ##NO MISSING VALUES
# Out:
# Credit_Amount             0
# Gender                    0
# Academic_Qualification    0
# Marital                   0
# Age_Years                 0
# Repayment_Status_Jan      0
# Repayment_Status_Feb      0
# Repayment_Status_March    0
# Repayment_Status_April    0
# Repayment_Status_May      0
# Repayment_Status_June     0
# Jan_Bill_Amount           0
# Feb_Bill_Amount           0
# March_Bill_Amount         0
# April_Bill_Amount         0
# May_Bill_Amount           0
# June_Bill_Amount          0
# Previous_Payment_Jan      0
# Previous_Payment_Feb      0
# Previous_Payment_March    0
# Previous_Payment_April    0
# Previous_Payment_May      0
# Previous_Payment_June     0
# Default_Payment           0
# dtype: int64

# %%
col_data=my_data.columns
col_data
# Out:
# Index(['Credit_Amount', 'Gender', 'Academic_Qualification', 'Marital',
#        'Age_Years', 'Repayment_Status_Jan', 'Repayment_Status_Feb',
#        'Repayment_Status_March', 'Repayment_Status_April',
#        'Repayment_Status_May', 'Repayment_Status_June', 'Jan_Bill_Amount',
#        'Feb_Bill_Amount', 'March_Bill_Amount', 'April_Bill_Amount',
#        'May_Bill_Amount', 'June_Bill_Amount', 'Previous_Payment_Jan',
#        'Previous_Payment_Feb', 'Previous_Payment_March',
#        'Previous_Payment_April', 'Previous_Payment_May',
#        'Previous_Payment_June', 'Default_Payment'],
#       dtype='object')

# %%
col_data.shape
# Out:
# (24,)

# %%
colur_data=["c","gray","purple","hotpink","dodgerblue",
            "lightgreen","orange","skyblue","slategray","maroon",
            "olive","darkcyan","lightcoral",
            "palegreen","sandybrown","red","dimgrey","seagreen","rosybrown",
            "lime","yellow","navy","hotpink","turquoise"]

# %%
len(colur_data)
# Out:
# 24

# %%
values=range(1,30)

# %%
plt.figure(figsize=(11,11), facecolor='white')
plt.style.use('ggplot')

for i,j,k in zip(col_data,colur_data,values):
        ax = plt.subplot(5,5,k)
        plt.hist(my_data[i],facecolor=j)
        plt.xlabel(i)
plt.tight_layout()

# %%
plt.figure(figsize=(20,20)) 
sns.heatmap(my_data.corr(), annot=True,cmap ='RdYlGn')

# %%
plt.figure(figsize=(15,15)) 
plt.style.use('ggplot')
sns.boxplot(data = my_data,width=.8,orient="h")

# %%
my_data["Default_Payment"].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: Default_Payment, dtype: int64

# %%
height = [23364,6636]
bars = ('0','1')
plt.bar(bars, height,color=("green","red"))
plt.xlabel("count")
plt.ylabel("Default_Payment")
# Out:
# Text(0, 0.5, 'Default_Payment')

# %% [markdown]
# # this is imbalance datset lets balance:

# %%
from sklearn.utils import resample

# %%
df_majority=my_data[my_data.Default_Payment==0]
df_minority=my_data[my_data.Default_Payment==1]

# %%
df_minority_upsampled=resample(df_minority,replace=True,n_samples=23364,random_state=123)
my_data_upsampled=pd.concat([df_majority,df_minority_upsampled])

# %%
my_data_upsampled.head()
# Out:
#    Credit_Amount  Gender  Academic_Qualification  Marital  Age_Years  \
# 2        90000.0       2                       2        2         34
# 3        50000.0       2                       2        1         37
# 4        50000.0       1                       2        1         57
# 5        50000.0       1                       1        2         37
# 6       500000.0       1                       1        2         29
#
#    Repayment_Status_Jan  Repayment_Status_Feb  Repayment_Status_March  \
# 2                     0                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
# 5                     0                     0                       0
# 6                     0                     0                       0
#
#    Repayment_Status_April  Repayment_Status_May  ...  April_Bill_Amount  \
# 2                       0                     0  ...            24332.0
# 3                       0                     0  ...            29324.0
# 4                       0                     0  ...            20940.0
# 5                       0                     0  ...            29394.0
# 6                       0                     0  ...           542653.0
#
#    May_Bill_Amount  June_Bill_Amount  Previous_Payment_Jan  \
# 2          14848.0           15548.0                1619.0
# 3          28858.0           28547.0                3000.0
# 4          18146.0           18131.0                3000.0
# 5          18618.0           20024.0                3600.0
# 6         483003.0          473844.0               66000.0
#
#    Previous_Payment_Feb  Previous_Payment_March  Previous_Payment_April  \
# 2                2500.0                  1000.0                  1000.0
# 3                2029.0                  1200.0                  1100.0
# 4               36672.0                 10000.0                  9000.0
# 5                2725.0                   657.0                  1000.0
# 6               40000.0                 59000.0                 30339.0
#
#    Previous_Payment_May  Previous_Payment_June  Default_Payment
# 2                1000.0                 5000.0                0
# 3                1069.0                 1000.0                0
# 4                 689.0                  679.0                0
# 5                1000.0                  800.0                0
# 6               13750.0                13770.0                0
#
# [5 rows x 24 columns]

# %%
my_data_upsampled.shape
# Out:
# (46728, 24)

# %%
my_data_upsampled.Default_Payment.value_counts()
# Out:
# 1    23364
# 0    23364
# Name: Default_Payment, dtype: int64

# %%
X=my_data_upsampled.drop(["Default_Payment"],1)

# %%
y=my_data_upsampled["Default_Payment"]

# %%
X.shape
# Out:
# (46728, 23)

# %%
y.shape
# Out:
# (46728,)

# %% [markdown]
# # Importance of Features

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection=ExtraTreesRegressor()
selection.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
selection.feature_importances_
# Out:
# array([0.06840498, 0.01843235, 0.04072733, 0.02717974, 0.07478906,
#        0.10416198, 0.05411992, 0.02591342, 0.0217307 , 0.01060963,
#        0.01294804, 0.0561846 , 0.04615124, 0.04280967, 0.04311357,
#        0.04208316, 0.04190077, 0.04659475, 0.04408877, 0.04493431,
#        0.04280187, 0.0433046 , 0.04701555])

# %%
importance_values=(selection.feature_importances_)*100
col_names_data=X.columns

# %%
col_names_data
# Out:
# Index(['Credit_Amount', 'Gender', 'Academic_Qualification', 'Marital',
#        'Age_Years', 'Repayment_Status_Jan', 'Repayment_Status_Feb',
#        'Repayment_Status_March', 'Repayment_Status_April',
#        'Repayment_Status_May', 'Repayment_Status_June', 'Jan_Bill_Amount',
#        'Feb_Bill_Amount', 'March_Bill_Amount', 'April_Bill_Amount',
#        'May_Bill_Amount', 'June_Bill_Amount', 'Previous_Payment_Jan',
#        'Previous_Payment_Feb', 'Previous_Payment_March',
#        'Previous_Payment_April', 'Previous_Payment_May',
#        'Previous_Payment_June'],
#       dtype='object')

# %%
dict_data={"feature":col_names_data,"importance":importance_values}
importance_data=pd.DataFrame(dict_data)
importance_data=importance_data.sort_values(by=['importance']) 
importance_data
# Out:
#                    feature  importance
# 9     Repayment_Status_May    1.060963
# 10   Repayment_Status_June    1.294804
# 1                   Gender    1.843235
# 8   Repayment_Status_April    2.173070
# 7   Repayment_Status_March    2.591342
# 3                  Marital    2.717974
# 2   Academic_Qualification    4.072733
# 16        June_Bill_Amount    4.190077
# 15         May_Bill_Amount    4.208316
# 20  Previous_Payment_April    4.280187
# 13       March_Bill_Amount    4.280967
# 14       April_Bill_Amount    4.311357
# 21    Previous_Payment_May    4.330460
# 18    Previous_Payment_Feb    4.408877
# 19  Previous_Payment_March    4.493431
# 12         Feb_Bill_Amount    4.615124
# 17    Previous_Payment_Jan    4.659475
# 22   Previous_Payment_June    4.701555
# 6     Repayment_Status_Feb    5.411992
# 11         Jan_Bill_Amount    5.618460
# 0            Credit_Amount    6.840498
# 4                Age_Years    7.478906
# 5     Repayment_Status_Jan   10.416198

# %%
plt.figure(figsize=(15,15))
barlist=plt.barh(list(importance_data["feature"]), (list(importance_data["importance"])),color=("orange")) 
barlist[22].set_color('g')
barlist[21].set_color('g')
barlist[20].set_color('g')
barlist[19].set_color('g')
barlist[0].set_color('r')
barlist[1].set_color('r')
barlist[2].set_color('r')
barlist[3].set_color('r')
barlist[4].set_color('r')
barlist[5].set_color('r')
plt.xlabel("Courses offered") 
plt.ylabel("No. of students enrolled") 
plt.title("Students enrolled in different courses")

plt.show()

# %%
X=X.drop(['Gender','Marital','Repayment_Status_March','Repayment_Status_May', 'Repayment_Status_June','Repayment_Status_April'],1)

# %%
X.shape
# Out:
# (46728, 17)

# %% [markdown]
# ## Train Test Split:

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

x_transform = scalar.fit_transform(X)
x_transform
# Out:
# array([[-0.68629258,  0.16997538, -0.16693673, ..., -0.22928784,
#         -0.23154377,  0.02687821],
#        [-0.99243914,  0.16997538,  0.15349182, ..., -0.22254966,
#         -0.22714834, -0.21640778],
#        [-0.99243914,  0.16997538,  2.28968217, ...,  0.30976599,
#         -0.25135509, -0.23593148],
#        ...,
#        [-1.22204907,  0.16997538,  0.68753941, ..., -0.19559697,
#         -0.29524576, -0.17991488],
#        [-1.14551243,  0.16997538, -1.34184142, ..., -0.29666956,
#          0.03084469, -0.27722927],
#        [ 1.38019672,  0.16997538,  1.64882507, ..., -0.29666956,
#         -0.29524576, -0.23915502]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x_transform,y,test_size = 0.30, random_state= 30)

# %%
X_train.shape
# Out:
# (32709, 17)

# %%
X_test.shape
# Out:
# (14019, 17)

# %% [markdown]
# # Model Building

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn1=KNeighborsClassifier(n_neighbors=5)

# %%
knn1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1=knn1.predict(X_test)

# %%
y_pred1
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)       #  withput 0.7424210000713317         #only with importacne  0.7408517012625723
# Out:
# 0.7408517012625723

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred1)
# Out:
# array([[4719, 2343],
#        [1290, 5667]], dtype=int64)

# %%
error_rate=[]
for i in range (1,25):
    knn= KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i=knn.predict(X_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
error_rate
# Out:
# [0.13060845994721448,
#  0.17768742421000072,
#  0.21456594621584993,
#  0.24017404950424423,
#  0.2591482987374278,
#  0.2688494186461231,
#  0.2732006562522291,
#  0.2781938797346458,
#  0.2839004208574078,
#  0.2821171267565447,
#  0.28546971966616735,
#  0.28461373849775307,
#  0.2881803266994793,
#  0.2894642984521007,
#  0.2943148584064484,
#  0.2923889007775162,
#  0.2936015407661031,
#  0.29681147014765674,
#  0.29937941365289966,
#  0.29937941365289966,
#  0.3039446465511092,
#  0.2980241101362437,
#  0.30023539482131395,
#  0.29937941365289966]

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,25),error_rate)
plt.xlabel('k')
plt.ylabel("Error Rate")
plt.style.use('ggplot')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'n_neighbors' : [3,5,7,9,10,11,13,15,17,19]}

# %%
knn_cv=GridSearchCV(knn1,param_grid,cv=10)
knn_cv.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 10, 11, 13, 15, 17, 19]})

# %%
knn_cv.best_params_
# Out:
# {'n_neighbors': 3}

# %% [markdown]
# # Building model with best Parameter

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[4894, 2168],
#        [ 840, 6117]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)        #0.7885013196376346
# Out:
# 0.7854340537841501

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76      7062
#            1       0.74      0.88      0.80      6957
#
#     accuracy                           0.79     14019
#    macro avg       0.80      0.79      0.78     14019
# weighted avg       0.80      0.79      0.78     14019

# %%
from sklearn.metrics import roc_curve
y_pred_proba = knn.predict_proba(X_test)[:,1]
y_pred_proba
# Out:
# array([0.        , 0.66666667, 0.66666667, ..., 0.66666667, 1.        ,
#        0.        ])

# %%
from sklearn.metrics import roc_auc_score
legend_data=roc_auc_score(y_test,y_pred_proba)
legend_data=round(legend_data,4)
legend_data                                        #0.8538
# Out:
# 0.8512

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
print('FPR')
print(fpr)
print('TPR')
print(tpr)
print('Thresholds')
print(thresholds)
# Out:
# FPR
# [0.         0.13579722 0.30699519 0.46601529 1.        ]
# TPR
# [0.         0.65804226 0.8792583  0.97542044 1.        ]
# Thresholds
# [2.         1.         0.66666667 0.33333333 0.        ]

# %%
plt.style.use('ggplot')
plt.plot(fpr,tpr, label='Knn',color='orange')
plt.plot([0,1],[0,1],'k--',color='navy')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title(' ROC curve')
plt.legend(["AUC=0.8512"], loc ="lower right") 
plt.show()
